# %% [raw]
# ---
# title: "Example Document"
# author: "Grant Patten"
# date: "20 September 2016"
# output:
#     pdf_document:
#         theme: readable
#         highlight: zenburn
# ---

# %% [markdown]
# # Include False

# %%
#r include=FALSE
print("include=FALSE")
plot(c(1,2,3), c(4,5,6))
# Out:
# [1] "include=FALSE"
# plot without title

# %% [markdown]
# # Echo=False

# %%
#r echo=FALSE
print("echo=FALSE")
plot(c(1,2,3), c(4,5,6))
# Out:
# [1] "What about this?"

# %% [markdown]
# # No Chunk Options

# %%
print("No Chunk Options")
plot(c(1,2,3), c(4,5,6))
# Out:
# [1] "No Chunk Options"
# plot without title

# %% [markdown]
# \newpage
# # New Page

# %%
# Example Plot
plot(c(1,2,3), c(4,5,6))
# Out:
# plot without title
